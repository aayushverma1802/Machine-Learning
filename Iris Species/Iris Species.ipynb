# %%
# Importing pandas to use in our code as pd.
import pandas as pd

# %%
# Reading the dataset “Iris.csv”.
data=pd.read_csv("C:\\Users\\aayus\\Downloads\\archive\\Iris.csv")

# %%
# Displaying up the top rows of the dataset with their columns 
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Displaying the number of rows randomly. 
data.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 132  133            6.4           2.8            5.6           2.2
# 91    92            6.1           3.0            4.6           1.4
# 101  102            5.8           2.7            5.1           1.9
# 115  116            6.4           3.2            5.3           2.3
# 49    50            5.0           3.3            1.4           0.2
# 21    22            5.1           3.7            1.5           0.4
# 111  112            6.4           2.7            5.3           1.9
# 60    61            5.0           2.0            3.5           1.0
# 134  135            6.1           2.6            5.6           1.4
# 35    36            5.0           3.2            1.2           0.2
#
#              Species
# 132   Iris-virginica
# 91   Iris-versicolor
# 101   Iris-virginica
# 115   Iris-virginica
# 49       Iris-setosa
# 21       Iris-setosa
# 111   Iris-virginica
# 60   Iris-versicolor
# 134   Iris-virginica
# 35       Iris-setosa

# %%
# Displaying the number of columns and names of the columns.
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# Displaying the shape of the dataset. 
# The first one is the number of rows and 
# the other one is the number of columns.
data.shape
# Out:
# (150, 6)

# %%
print(data)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
# Slicing the rows. 

# data[start:end]
# start is inclusive whereas end is exclusive
print(data[10:21])
# it will print the rows from 10 to 20.

# you can also save for in varaible for the future use
sliced_data=data[10:21]
print(sliced_data)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 16  17            5.4           3.9            1.3           0.4  Iris-setosa
# 17  18            5.1           3.5            1.4           0.3  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
# 19  20            5.1           3.8            1.5           0.3  Iris-setosa
# 20  21            5.4           3.4            1.7           0.2  Iris-setosa
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 16  17            5.4           3.9            1.3           0.4  Iris-setosa
# 17  18            5.1           3.5            1.4           0.3  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
# 19  20            5.1           3.8            1.5           0.3  Iris-setosa
# 20  21            5.4           3.4            1.7           0.2  Iris-setosa

# %%
# Displaying only specific columns. 

#here in the case of Iris dataset
#we will save it in a another variable named "specific_data"
specific_data=data[["Id","Species"]]

#data[["column_name1","column_name2","column_name3"]]
#now we will print the first 10 columns of the specific_data dataframe.

print(specific_data.head(10))
# Out:
#    Id      Species
# 0   1  Iris-setosa
# 1   2  Iris-setosa
# 2   3  Iris-setosa
# 3   4  Iris-setosa
# 4   5  Iris-setosa
# 5   6  Iris-setosa
# 6   7  Iris-setosa
# 7   8  Iris-setosa
# 8   9  Iris-setosa
# 9  10  Iris-setosa

# %%
#Filtering: Displaying the specific rows using “iloc” and “loc” functions. 

#here we will use iloc
data.iloc[5]
# Out:
# Id                         6
# SepalLengthCm            5.4
# SepalWidthCm             3.9
# PetalLengthCm            1.7
# PetalWidthCm             0.4
# Species          Iris-setosa
# Name: 5, dtype: object

# %%
#it will display records only with species "Iris-setosa".

data.loc[data["Species"]=="Iris-setosa"]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 16  17            5.4           3.9            1.3           0.4  Iris-setosa
# 17  18            5.1           3.5            1.4           0.3  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
# 19  20            5.1           3.8            1.5           0.3  Iris-setosa
# 20  21            5.4           3.4            1.7           0.2  Iris-setosa
# 21  22            5.1           3.7            1.5           0.4  Iris-setosa
# 22  23            4.6           3.6            1.0           0.2  Iris-setosa
# 23  24            5.1           3.3            1.7           0.5  Iris-setosa
# 24  25            4.8           3.4            1.9           0.2  Iris-setosa
# 25  26            5.0           3.0            1.6           0.2  Iris-setosa
# 26  27            5.0           3.4            1.6           0.4  Iris-setosa
# 27  28            5.2           3.5            1.5           0.2  Iris-setosa
# 28  29            5.2           3.4            1.4           0.2  Iris-setosa
# 29  30            4.7           3.2            1.6           0.2  Iris-setosa
# 30  31            4.8           3.1            1.6           0.2  Iris-setosa
# 31  32            5.4           3.4            1.5           0.4  Iris-setosa
# 32  33            5.2           4.1            1.5           0.1  Iris-setosa
# 33  34            5.5           4.2            1.4           0.2  Iris-setosa
# 34  35            4.9           3.1            1.5           0.1  Iris-setosa
# 35  36            5.0           3.2            1.2           0.2  Iris-setosa
# 36  37            5.5           3.5            1.3           0.2  Iris-setosa
# 37  38            4.9           3.1            1.5           0.1  Iris-setosa
# 38  39            4.4           3.0            1.3           0.2  Iris-setosa
# 39  40            5.1           3.4            1.5           0.2  Iris-setosa
# 40  41            5.0           3.5            1.3           0.3  Iris-setosa
# 41  42            4.5           2.3            1.3           0.3  Iris-setosa
# 42  43            4.4           3.2            1.3           0.2  Iris-setosa
# 43  44            5.0           3.5            1.6           0.6  Iris-setosa
# 44  45            5.1           3.8            1.9           0.4  Iris-setosa
# 45  46            4.8           3.0            1.4           0.3  Iris-setosa
# 46  47            5.1           3.8            1.6           0.2  Iris-setosa
# 47  48            4.6           3.2            1.4           0.2  Iris-setosa
# 48  49            5.3           3.7            1.5           0.2  Iris-setosa
# 49  50            5.0           3.3            1.4           0.2  Iris-setosa

# %%
data.iloc[5]
data.loc[data["Species"] == "Iris-setosa"]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 16  17            5.4           3.9            1.3           0.4  Iris-setosa
# 17  18            5.1           3.5            1.4           0.3  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
# 19  20            5.1           3.8            1.5           0.3  Iris-setosa
# 20  21            5.4           3.4            1.7           0.2  Iris-setosa
# 21  22            5.1           3.7            1.5           0.4  Iris-setosa
# 22  23            4.6           3.6            1.0           0.2  Iris-setosa
# 23  24            5.1           3.3            1.7           0.5  Iris-setosa
# 24  25            4.8           3.4            1.9           0.2  Iris-setosa
# 25  26            5.0           3.0            1.6           0.2  Iris-setosa
# 26  27            5.0           3.4            1.6           0.4  Iris-setosa
# 27  28            5.2           3.5            1.5           0.2  Iris-setosa
# 28  29            5.2           3.4            1.4           0.2  Iris-setosa
# 29  30            4.7           3.2            1.6           0.2  Iris-setosa
# 30  31            4.8           3.1            1.6           0.2  Iris-setosa
# 31  32            5.4           3.4            1.5           0.4  Iris-setosa
# 32  33            5.2           4.1            1.5           0.1  Iris-setosa
# 33  34            5.5           4.2            1.4           0.2  Iris-setosa
# 34  35            4.9           3.1            1.5           0.1  Iris-setosa
# 35  36            5.0           3.2            1.2           0.2  Iris-setosa
# 36  37            5.5           3.5            1.3           0.2  Iris-setosa
# 37  38            4.9           3.1            1.5           0.1  Iris-setosa
# 38  39            4.4           3.0            1.3           0.2  Iris-setosa
# 39  40            5.1           3.4            1.5           0.2  Iris-setosa
# 40  41            5.0           3.5            1.3           0.3  Iris-setosa
# 41  42            4.5           2.3            1.3           0.3  Iris-setosa
# 42  43            4.4           3.2            1.3           0.2  Iris-setosa
# 43  44            5.0           3.5            1.6           0.6  Iris-setosa
# 44  45            5.1           3.8            1.9           0.4  Iris-setosa
# 45  46            4.8           3.0            1.4           0.3  Iris-setosa
# 46  47            5.1           3.8            1.6           0.2  Iris-setosa
# 47  48            4.6           3.2            1.4           0.2  Iris-setosa
# 48  49            5.3           3.7            1.5           0.2  Iris-setosa
# 49  50            5.0           3.3            1.4           0.2  Iris-setosa

# %%
# Counting the number of counts of unique values using “value_counts()”. 

#In this dataset we will work on the Species column, it will count number of times a particular species has occurred.
data["Species"].value_counts()
#it will display in descending order.
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
# Calculating sum, mean and mode of a particular column. 

# data["column_name"].sum()

sum_data=data["SepalLengthCm"].sum()
mean_data=data["SepalLengthCm"].mean()
median_data=data["SepalLengthCm"].median()

print("Sum:",sum_data,"\nMean:",mean_data,"\nMedian:",median_data)
# Out:
# Sum: 876.5
# Mean: 5.843333333333335
# Median: 5.8

# %%
# Extracting minimum and maximum from a column. 

min_data=data["SepalLengthCm"].min()
max_data=data["SepalLengthCm"].max()

print("Minmum",min_data,"\nMaximum",max_data)
# Out:
# Minmum 4.3
# Maximum 7.9

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2cfd8_row13_col0" class="data row13 col0" >14</td>
#       <td id="T_2cfd8_row13_col1" class="data row13 col1" >4.300000</td>
#       <td id="T_2cfd8_row13_col2" class="data row13 col2" >3.000000</td>
#       <td id="T_2cfd8_row13_col3" class="data row13 col3" >1.100000</td>
#       <td id="T_2cfd8_row13_col4" class="data row13 col4" >0.100000</td>
#       <td id="T_2cfd8_row13_col5" class="data row13 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_2cfd8_level0_row14" class="row_headin

# %%
data.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_777f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_777f5_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_777f5_level0_col1" class="col_heading level0 col1" >SepalLengthCm</th>
#       <th id="T_777f5_level0_col2" class="col_heading level0 col2" >sepalwidth</th>
#       <th id="T_777f5_level0_col3" class="col_heading level0 col3" >PetalLengthCm</th>
#       <th id="T_777f5_level0_col4" class="col_heading level0 col4" >PetalWidthCm</th>
#       <th id="T_777f5_level0_col5" class="col_heading level0 col5" >Species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_777f5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_777f5_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_777f5_row0_col1" class="data row0 col1" >5.100000</td>
#       <td id="T_777f5_row0_col2" class="data row0 col2" >3.500000</td>
#       <td id="T_777f5_row0_col3" class="data row0 col3" >1.400000</td>
#       <td id="T_777f5_row0_col4" class="data row0 col4" >0.200000</td>
#       <td id="T_777f5_row0_col5" class="data row0 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_777f5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_777f5_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_777f5_row1_col1" class="data row1 col1" >4.900000</td>
#       <td id="T_777f5_row1_col2" class="data row1 col2" >3.000000</td>
#       <td id="T_777f5_row1_col3" class="data row1 col3" >1.400000</td>
#       <td id="T_777f5_row1_col4" class="data row1 col4" >0.200000</td>
#       <td id="T_777f5_row1_col5" class="data row1 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_777f5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_777f5_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_777f5_row2_col1" class="data row2 col1" >4.700000</td>
#       <td id="T_777f5_row2_col2" class="data row2 col2" >3.200000</td>
#       <td id="T_777f5_row2_col3" class="data row2 col3" >1.300000</td>
#       <td id="T_777f5_row2_col4" class="data row2 col4" >0.200000</td>
#       <td id="T_777f5_row2_col5" class="data row2 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_777f5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_777f5_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_777f5_row3_col1" class="data row3 col1" >4.600000</td>
#       <td id="T_777f5_row3_col2" class="data row3 col2" >3.100000</td>
#       <td id="T_777f5_row3_col3" class="data row3 col3" >1.500000</td>
#       <td id="T_777f5_row3_col4" class="data row3 col4" >0.200000</td>
#       <td id="T_777f5_row3_col5" class="data row3 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_777f5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_777f5_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_777f5_row4_col1" class="data row4 col1" >5.000000</td>
#       <td id="T_777f5_row4_col2" class="data row4 col2" >3.600000</td>
#       <td id="T_777f5_row4_col3" class="data row4 col3" >1.400000</td>
#       <td id="T_777f5_row4_col4" class="data row4 col4" >0.200000</td>
#       <td id="T_777f5_row4_col5" class="data row4 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_777f5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_777f5_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_777f5_row5_col1" class="data row5 col1" >5.400000</td>
#       <td id="T_777f5_row5_col2" class="data row5 col2" >3.900000</td>
#       <td id="T_777f5_row5_col3" class="data row5 col3" >1.700000</td>
#       <td id="T_777f5_row5_col4" class="data row5 col4" >0.400000</td>
#       <td id="T_777f5_row5_col5" class="data row5 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_777f5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_777f5_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_777f5_row6_col1" class="data row6 col1" >4.600000</td>
#       <td id="T_777f5_row6_col2" class="data row6 col2" >3.400000</td>
#       <td id="T_777f5_row6_col3" class="data row6 col3" >1.400000</td>
#       <td id="T_777f5_row6_col4" class="data row6 col4" >0.300000</td>
#       <td id="T_777f5_row6_col5" class="data row6 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_777f5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_777f5_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_777f5_row7_col1" class="data row7 col1" >5.000000</td>
#       <td id="T_777f5_row7_col2" class="data row7 col2" >3.400000</td>
#       <td id="T_777f5_row7_col3" class="data row7 col3" >1.500000</td>
#       <td id="T_777f5_row7_col4" class="data row7 col4" >0.200000</td>
#       <td id="T_777f5_row7_col5" class="data row7 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_777f5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_777f5_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_777f5_row8_col1" class="data row8 col1" >4.400000</td>
#       <td id="T_777f5_row8_col2" class="data row8 col2" >2.900000</td>
#       <td id="T_777f5_row8_col3" class="data row8 col3" >1.400000</td>
#       <td id="T_777f5_row8_col4" class="data row8 col4" >0.200000</td>
#       <td id="T_777f5_row8_col5" class="data row8 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_777f5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_777f5_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_777f5_row9_col1" class="data row9 col1" >4.900000</td>
#       <td id="T_777f5_row9_col2" class="data row9 col2" >3.100000</td>
#       <td id="T_777f5_row9_col3" class="data row9 col3" >1.500000</td>
#       <td id="T_777f5_row9_col4" class="data row9 col4" >0.100000</td>
#       <td id="T_777f5_row9_col5" class="data row9 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_777f5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_777f5_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_777f5_row10_col1" class="data row10 col1" >5.400000</td>
#       <td id="T_777f5_row10_col2" class="data row10 col2" >3.700000</td>
#       <td id="T_777f5_row10_col3" class="data row10 col3" >1.500000</td>
#       <td id="T_777f5_row10_col4" class="data row10 col4" >0.200000</td>
#       <td id="T_777f5_row10_col5" class="data row10 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_777f5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_777f5_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_777f5_row11_col1" class="data row11 col1" >4.800000</td>
#       <td id="T_777f5_row11_col2" class="data row11 col2" >3.400000</td>
#       <td id="T_777f5_row11_col3" class="data row11 col3" >1.600000</td>
#       <td id="T_777f5_row11_col4" class="data row11 col4" >0.200000</td>
#       <td id="T_777f5_row11_col5" class="data row11 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_777f5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_777f5_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_777f5_row12_col1" class="data row12 col1" >4.800000</td>
#       <td id="T_777f5_row12_col2" class="data row12 col2" >3.000000</td>
#       <td id="T_777f5_row12_col3" class="data row12 col3" >1.400000</td>
#       <td id="T_777f5_row12_col4" class="data row12 col4" >0.100000</td>
#       <td id="T_777f5_row12_col5" class="data row12 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_777f5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_777f5_row13_col0" class="data row13 col0" >14</td>
#       <td id="T_777f5_row13_col1" class="data row13 col1" >4.300000</td>
#       <td id="T_777f5_row13_col2" class="data row13 col2" >3.000000</td>
#       <td id="T_777f5_row13_col3" class="data row13 col3" >1.100000</td>
#       <td id="T_777f5_row13_col4" class="data row13 col4" >0.100000</td>
#       <td id="T_777f5_row13_col5" class="data row13 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_777f5_level0_row14" class="row_headin

# %%
# we will here print only the top 10 rows of the dataset, 
# if you want to see the result of the whole dataset remove 
#.head(10) from the below code
  
data.head(10).style.highlight_max(color='lightgreen', axis=0)
  
data.head(10).style.highlight_max(color='lightgreen', axis=1)
  
data.head(10).style.highlight_max(color='lightgreen', axis=None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style.py in _repr_html_(self)
#     270         """
#     271         if get_option("styler.render.repr") == "html":
# --> 272             return self.to_html()
#     273         return None
#     274
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style.py in to_html(self, buf, table_uuid, table_attributes, sparse_index, sparse_columns, bold_headers, caption, max_rows, max_columns, encoding, doctype_html, exclude_styles, **kwargs)
#    1177
#    1178         # Build HTML string..
# -> 1179         html = obj._render_html(
#    1180             sparse_index=sparse_index,
#    1181             sparse_columns=sparse_columns,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style_render.py in _render_html(self, sparse_index, sparse_columns, max_rows, max_cols, **kwargs)
#     160         Generates a dict with necessary kwargs passed to jinja2 template.
#     161         """
# --> 162         self._compute()
#     163         # TODO: namespace all the pandas keys
#     164         d = self._translate(sparse_index, sparse_columns, max_rows, max_cols)
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style_render.py in _compute(self)
#     203         r = self
#     204         for func, args, kwargs in self._todo:
# --> 205             r = func(self)(*args, **kwargs)
#     206         return r
#     207
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style.py in _apply(self, func, axis, subset, **kwargs)
#    1423         data = self.data.loc[subset]
#    1424         if axis is None:
# -> 1425             result = func(data, **kwargs)
#    1426             if not isinstance(result, DataFrame):
#    1427                 if not isinstance(result, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style.py in _highlight_value(data, op, props)
#    3660     value = getattr(data, op)(skipna=True)
#    3661     if isinstance(data, DataFrame):  # min/max must be done twice to return scalar
# -> 3662         value = getattr(value, op)(skipna=True)
#    3663     cond = data == value
#    3664     cond = cond.where(pd.notna(cond), False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in max(self, axis, skipna, level, numeric_only, **kwargs)
#   11217             **kwargs,
#   11218         ):
# > 11219             return NDFrame.max(self, axis, skipna, level, numeric_only, **kwargs)
#   11220
#   11221         setattr(cls, "max", max)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in max(self, axis, skipna, level, numeric_only, **kwargs)
#   10674         **kwargs,
#   10675     ):
# > 10676         return self._stat_function(
#   10677             "max",
#   10678             nanops.nanmax,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10644                 name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   10645             )
# > 10646         return self._reduce(
#   10647             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10648         )
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4469                 )
#    4470             with np.errstate(all="ignore"):
# -> 4471                 return op(delegate, skipna=skipna, **kwds)
#    4472
#    4473     def _reindex_indexer(
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     153                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154             else:
# --> 155                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     156
#     157             return result
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     408             mask = isna(values)
#     409
# --> 410         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     411
#     412         if datetimelike:
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in reduction(values, axis, skipna, mask)
#    1041                 result = np.nan
#    1042         else:
# -> 1043             result = getattr(values, meth)(axis)
#    1044
#    1045         result = _maybe_null_out(result, axis, mask, values.shape)
#
# ~\anaconda3\lib\site-packages\numpy\core\_methods.py in _amax(a, axis, out, keepdims, initial, where)
#      38 def _amax(a, axis=None, out=None, keepdims=False,
#      39           initial=_NoValue, where=True):
# ---> 40     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#      41
#      42 def _amin(a, axis=None, out=None, keepdims=False,
#
# TypeError: '>=' not supported between instances of 'numpy.ndarray' and 'str'

# %%
# Cleaning and detecting missing values 
data.isnull()
# Out:
#         id  SepalLengthCm  sepalwidth  PetalLengthCm  PetalWidthCm  Species
# 0    False          False       False          False         False    False
# 1    False          False       False          False         False    False
# 2    False          False       False          False         False    False
# 3    False          False       False          False         False    False
# 4    False          False       False          False         False    False
# ..     ...            ...         ...            ...           ...      ...
# 145  False          False       False          False         False    False
# 146  False          False       False          False         False    False
# 147  False          False       False          False         False    False
# 148  False          False       False          False         False    False
# 149  False          False       False          False         False    False
#
# [150 rows x 6 columns]

# %%
# Summarizing the missing values. 
data.isnull().sum()
# Out:
# id               0
# SepalLengthCm    0
# sepalwidth       0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# Heatmap: Importing seaborn 
import seaborn as sns
  
iris = sns.load_dataset("iris")
sns.heatmap(iris.corr(), cmap="YlGnBu", linecolor = 'white',linewidths = 1)
# Out:
# <AxesSubplot:>

# %%
# Pandas Dataframe Correlation: 
data.corr(method="pearson")
# Out:
#                      id  SepalLengthCm  sepalwidth  PetalLengthCm  \
# id             1.000000       0.716676   -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000   -0.109369       0.871754
# sepalwidth    -0.397729      -0.109369    1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754   -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954   -0.356544       0.962757
#
#                PetalWidthCm
# id                 0.899759
# SepalLengthCm      0.817954
# sepalwidth        -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
# Multivariate Analysis: 
g = sns.pairplot(data,hue="Species")
